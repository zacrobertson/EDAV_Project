# %% [markdown]
# # Introduction
#
# As technology has progressed and allowed people to consume news in ways that previous generations could not, news opinions have diversified to capture niche segments of different audiences. Even mainstream news sources are popularly known to "lean" one direction or another, and

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# %matplotlib inline

from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import datetime
from time import sleep
import collections
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from textblob import TextBlob

# %%
data = pd.read_csv('filtered_data.csv')

# %%
data
# Out:
#        Unnamed: 0  show_index  \
# 0               0           0
# 1               2           2
# 2               3           3
# 3               4           4
# 4               5           5
# 5               7           7
# 6               8           8
# 7               9           9
# 8              10          10
# 9              11          11
# 10             12          12
# 11             13          13
# 12             14          14
# 13             16          16
# 14             17          17
# 15             18          18
# 16             19          19
# 17             21          21
# 18             22          22
# 19             23          23
# 20             24          24
# 21             25          25
# 22             26          26
# 23             27          27
# 24             28          28
# 25             29          29
# 26             31          31
# 27             32          32
# 28             33          33
# 29             35          35
# ...
